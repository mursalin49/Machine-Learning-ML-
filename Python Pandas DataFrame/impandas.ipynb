# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 837.5 kB/s eta 0:00:14
#    - -------------------------------------- 0.5/11.5 MB 837.5 kB/s eta 0:00:14
#    -- ------------------------------------- 0.8/11.5 MB 780.2 kB/s eta 0:00:14
#    --- ------------------------------------ 1.0/11.5 MB 774.0 kB/s eta 0:00:14
#    --- ------------------------------------ 1.0/11.5 MB 774.0 kB/s eta 0:00:14
#    ---- ----------------------------------- 1.3/11.5 MB 753.8 kB/s eta 0:00:14
#    ---- ----------------------------------- 1.3/11.5 MB 753.8 kB/s eta 0:00:14
#    ----- ---------------------------------- 1.6/11.5 MB 749.0 kB/s eta 0:00:14
# ...

# %%
import pandas as pd

# %%
#dataset
data = { 
    'student': ["Nirob", "Mamun", " Sobuj", "Hasan", " Mursalin"],
        'rank': [1,4,3,5,2],
        'marks': [90,70,80,60,92]
       }
res = pd.DataFrame(data)
print("Student Records\n\n",res)
# Out:
# Student Records
#
#       student  rank  marks
# 0      Nirob     1     90
# 1      Mamun     4     70
# 2      Sobuj     3     80
# 3      Hasan     5     60
# 4   Mursalin     2     92
